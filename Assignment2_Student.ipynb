# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="Rossum"></p>
#
#
# ____

# %%
import pandas as pd
import numpy as np

# %%
ecom = pd.read_csv('data.csv',encoding= 'unicode_escape')

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
ecom.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ** How many rows and columns are there? **

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# ** Show the statistical measurements of ecom dataset **

# %%
ecom.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# ** What is the average Purchase Price? **

# %%
ecom.UnitPrice.mean()
# Out:
# 4.611113626088513

# %% [markdown]
# ** What were the highest and lowest purchase prices? **

# %%
ecom.UnitPrice.max()
# Out:
# 38970.0

# %%
ecom.UnitPrice.min()
# Out:
# -11062.06

# %% [markdown]
# ** List the country names and number of records belongs to each country **

# %%
ecom["Country"].value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Country, dtype: int64

# %% [markdown]
# ** How many records are as Country United Kingdom? **

# %%
ecom[ecom["Country"] == "United Kingdom"].count()
# Out:
# InvoiceNo      495478
# StockCode      495478
# Description    494024
# Quantity       495478
# InvoiceDate    495478
# UnitPrice      495478
# CustomerID     361878
# Country        495478
# dtype: int64

# %% [markdown]
# ** Create a column named Total which shows the total amount of spend using UnitPrice and Quantity ? **

# %%
ecom["Total"] = ecom["UnitPrice"]*ecom.Quantity
ecom["Total"]
# Out:
# 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 541904    10.20
# 541905    12.60
# 541906    16.60
# 541907    16.60
# 541908    14.85
# Name: Total, Length: 541909, dtype: float64

# %% [markdown]
# ** Show total pending amount according to the Countries **

# %%
ecom.groupby("Country")["Total"].sum()/1000

# %% [markdown]
# ** Which Country spend least? **

# %%
ecom.groupby("Country")["Total"].sum().sort_values()[[0]]
# Out:
# Country
# Saudi Arabia    131.17
# Name: Total, dtype: float64

# %%
ecom.groupby("Country")["Total"].sum().sort_values(ascending=True)[:1]
# :1 in anlamı 0 dan başla 1. indexe kadar al
# Out:
# Country
# Saudi Arabia    131.17
# Name: Total, dtype: float64

# %% [markdown]
# ** Calculate average of spending according to country with apply function? **

# %%
ecom.groupby('Country')['Total'].apply(lambda x : x.mean())
# Out:
# Country
# Australia               108.877895
# Austria                  25.322494
# Bahrain                  28.863158
# Belgium                  19.773301
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          26.499063
# Cyprus                   20.813971
# Czech Republic           23.590667
# Denmark                  48.247147
# EIRE                     32.122599
# European Community       21.176230
# Finland                  32.124806
# France                   23.069288
# Germany                  23.348943
# Greece                   32.263836
# Hong Kong                35.128611
# Iceland                  23.681319
# Israel                   26.625657
# Italy                    21.034259
# Japan                    98.716816
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    19.728110
# Netherlands             120.059696
# Norway                   32.378877
# Poland                   21.152903
# Portugal                 19.333127
# RSA                      17.281207
# Saudi Arabia             13.117000
# Singapore                39.827031
# Spain                    21.624390
# Sweden                   79.211926
# Switzerland              28.164510
# USA                       5.948179
# United Arab Emirates     27.974706
# United Kingdom           16.525065
# Unspecified              10.649753
# Name: Total, dtype: float64

# %% [markdown]
# ** Calculate average,mean,max of spending according to country with agg function? **

# %%
ecom.groupby("Country")["Total"].agg({"min", "max", "mean"})
# Out:
#                             mean        min        max
# Country
# Australia             108.877895    -425.00    1718.40
# Austria                25.322494     -21.25     360.00
# Bahrain                28.863158    -205.74     205.74
# Belgium                19.773301     -19.95     165.00
# Brazil                 35.737500      15.00     175.20
# Canada                 24.280662       2.50     550.94
# Channel Islands        26.499063    -293.00     408.00
# Cyprus                 20.813971    -320.69     320.69
# Czech Republic         23.590667     -35.76      70.80
# Denmark                48.247147     -59.80     428.40
# EIRE                   32.122599   -1917.00    2365.20
# European Community     21.176230      -8.50      60.00
# Finland                32.124806     -80.00     551.20
# France                 23.069288   -8322.12    4161.06
# Germany                23.348943    -599.50     876.00
# Greece                 32.263836     -50.00     175.20
# Hong Kong              35.128611   -2653.95    2653.95
# Iceland                23.681319       5.04     249.60
# Israel                 26.625657    -136.00     350.40
# Italy                  21.034259     -89.55     300.00
# Japan                  98.716816   -1591.20    3794.40
# Lebanon                37.641778      10.20     153.00
# Lithuania              47.458857      13.20     122.40
# Malta                  19.728110    -130.00     455.00
# Netherlands           120.059696    -266.40    4992.00
# Norway                 32.378877    -376.50     700.00
# Poland                 21.152903     -39.80     120.00
# Portugal               19.333127   -1241.98    1241.98
# RSA                    17.281207       0.00      38.25
# Saudi Arabia           13.117000     -14.75      19.80
# Singapore              39.827031   -3949.32    3949.32
# Spain                  21.624390   -1715.85    1350.00
# Sweden                 79.211926   -1188.00    1188.00
# Switzerland            28.164510    -179.00     360.00
# USA                     5.948179     -74.88      81.36
# United Arab Emirates   27.974706       3.48     153.00
# United Kingdom         16.525065 -168469.60  168469.60
# Unspecified            10.649753       0.19      69.36

# %% [markdown]
# ** What is the max Total spending in whole dataset and show the records of that spending ?**

# %%
ecom.sort_values("Total",ascending=False).head(1)
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#            InvoiceDate  UnitPrice  CustomerID         Country     Total
# 540421  12/9/2011 9:15       2.08     16446.0  United Kingdom  168469.6

# %% [markdown]
# ** How many people who live in Spain spend more than average Total ?**

# %%
ecom[(ecom["Total"] > ecom["Total"].mean()) & (ecom["Country"] == "Spain")].count()
# Out:
# InvoiceNo      728
# StockCode      728
# Description    728
# Quantity       728
# InvoiceDate    728
# UnitPrice      728
# CustomerID     728
# Country        728
# Total          728
# dtype: int64

# %% [markdown]
# ** Convert datatype of InvoiceDate to datetime and assign it to new column name InvoiceDate2**

# %%
ecom['InvoiceDate2']=pd.to_datetime(ecom.InvoiceDate)
ecom['InvoiceDate2']
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate2, Length: 541909, dtype: datetime64[ns]

# %% [markdown]
# ** Take only date values (year-month-day) from InvoiceDate2 and assign it to a new column named date **

# %%
ecom["Date"] = pd.to_datetime(ecom.InvoiceDate2.dt.date)
ecom["Date"]
# Out:
# 0        2010-12-01
# 1        2010-12-01
# 2        2010-12-01
# 3        2010-12-01
# 4        2010-12-01
#             ...
# 541904   2011-12-09
# 541905   2011-12-09
# 541906   2011-12-09
# 541907   2011-12-09
# 541908   2011-12-09
# Name: Date, Length: 541909, dtype: datetime64[ns]

# %%
# Out:
# 0         2010-12-01
# 1         2010-12-01
# 2         2010-12-01
# 3         2010-12-01
# 4         2010-12-01
#              ...
# 541904    2011-12-09
# 541905    2011-12-09
# 541906    2011-12-09
# 541907    2011-12-09
# 541908    2011-12-09
# Name: date, Length: 541909, dtype: object

# %%
ecom.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#    UnitPrice  CustomerID         Country  Total       Date
# 0       2.55     17850.0  United Kingdom  15.30 2010-12-01
# 1       3.39     17850.0  United Kingdom  20.34 2010-12-01
# 2       2.75     17850.0  United Kingdom  22.00 2010-12-01
# 3       3.39     17850.0  United Kingdom  20.34 2010-12-01
# 4       3.39     17850.0  United Kingdom  20.34 2010-12-01

# %% [markdown]
# ** drop InvoiceDate2 and InvoiceDate columns permanently **

# %%
ecom.drop(columns=["InvoiceDate","InvoiceDate2"], inplace=True)
ecom.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\osman\OneDrive\Masaüstü\Kodlama\datascience\2-DA\Assignment2_Student.ipynb Cell 41' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/osman/OneDrive/Masa%C3%BCst%C3%BC/Kodlama/datascience/2-DA/Assignment2_Student.ipynb#ch0000040?line=0'>1</a> ecom.drop(columns=["InvoiceDate","InvoiceDate2"], inplace=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/osman/OneDrive/Masa%C3%BCst%C3%BC/Kodlama/datascience/2-DA/Assignment2_Student.ipynb#ch0000040?line=1'>2</a> ecom.head()
#
# File c:\Users\osman\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File c:\Users\osman\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4805'>4806</a> @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4806'>4807</a> def drop(
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4807'>4808</a>     self,
#    (...)
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4814'>4815</a>     errors: str = "raise",
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4815'>4816</a> ):
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4816'>4817</a>     """
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4817'>4818</a>     Drop specified labels from rows or columns.
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4818'>4819</a>
#    (...)
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4951'>4952</a>             weight  1.0     0.8
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4952'>4953</a>     """
# -> <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4953'>4954</a>     return super().drop(
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4954'>4955</a>         labels=labels,
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4955'>4956</a>         axis=axis,
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4956'>4957</a>         index=index,
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4957'>4958</a>         columns=columns,
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4958'>4959</a>         level=level,
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4959'>4960</a>         inplace=inplace,
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4960'>4961</a>         errors=errors,
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=4961'>4962</a>     )
#
# File c:\Users\osman\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4264'>4265</a> for axis, labels in axes.items():
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4265'>4266</a>     if labels is not None:
# -> <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4266'>4267</a>         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4268'>4269</a> if inplace:
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4269'>4270</a>     self._update_inplace(obj)
#
# File c:\Users\osman\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4308'>4309</a>         new_axis = axis.drop(labels, level=level, errors=errors)
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4309'>4310</a>     else:
# -> <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4310'>4311</a>         new_axis = axis.drop(labels, errors=errors)
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4311'>4312</a>     indexer = axis.get_indexer(new_axis)
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4313'>4314</a> # Case for non-unique axis
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/generic.py?line=4314'>4315</a> else:
#
# File c:\Users\osman\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=6641'>6642</a> if mask.any():
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=6642'>6643</a>     if errors != "ignore":
# -> <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=6643'>6644</a>         raise KeyError(f"{list(labels[mask])} not found in axis")
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=6644'>6645</a>     indexer = indexer[~mask]
#    <a href='file:///c%3A/Users/osman/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=6645'>6646</a> return self.delete(indexer)
#
# KeyError: "['InvoiceDate', 'InvoiceDate2'] not found in axis"

# %% [markdown]
# ** Remove A, B, G and E from first 5 rows of ecom dataframe with a string method **

# %%
ecom.StockCode[:5].str.replace('A','').str.replace('B','').str.replace('G','').str.replace('E','')
# Out:
# 0    85123
# 1    71053
# 2    84406
# 3    84029
# 4    84029
# Name: StockCode, dtype: object

# %% [markdown]
# ** take only Total and date columns with loc and craete a new df named ecom2 **

# %%
ecom2 = ecom.loc[:,["Total","Date"]]
ecom2
# Out:
#         Total       Date
# 0       15.30 2010-12-01
# 1       20.34 2010-12-01
# 2       22.00 2010-12-01
# 3       20.34 2010-12-01
# 4       20.34 2010-12-01
# ...       ...        ...
# 541904  10.20 2011-12-09
# 541905  12.60 2011-12-09
# 541906  16.60 2011-12-09
# 541907  16.60 2011-12-09
# 541908  14.85 2011-12-09
#
# [541909 rows x 2 columns]

# %% [markdown]
# ** take only InvoiceNo and CustomerID columns with iloc and craete a new df named ecom3 **

# %%
ecom3 = ecom.iloc[:,[0,5,7]]
ecom3
# Out:
#        InvoiceNo  CustomerID  Total
# 0         536365     17850.0  15.30
# 1         536365     17850.0  20.34
# 2         536365     17850.0  22.00
# 3         536365     17850.0  20.34
# 4         536365     17850.0  20.34
# ...          ...         ...    ...
# 541904    581587     12680.0  10.20
# 541905    581587     12680.0  12.60
# 541906    581587     12680.0  16.60
# 541907    581587     12680.0  16.60
# 541908    581587     12680.0  14.85
#
# [541909 rows x 3 columns]

# %% [markdown]
# ** Combine ecom2 and ecom3 with concat **

# %%
ecom_concat= pd.concat([ecom3, ecom2], axis=1)
ecom_concat
# Out:
#        InvoiceNo  CustomerID  Total  Total       Date
# 0         536365     17850.0  15.30  15.30 2010-12-01
# 1         536365     17850.0  20.34  20.34 2010-12-01
# 2         536365     17850.0  22.00  22.00 2010-12-01
# 3         536365     17850.0  20.34  20.34 2010-12-01
# 4         536365     17850.0  20.34  20.34 2010-12-01
# ...          ...         ...    ...    ...        ...
# 541904    581587     12680.0  10.20  10.20 2011-12-09
# 541905    581587     12680.0  12.60  12.60 2011-12-09
# 541906    581587     12680.0  16.60  16.60 2011-12-09
# 541907    581587     12680.0  16.60  16.60 2011-12-09
# 541908    581587     12680.0  14.85  14.85 2011-12-09
#
# [541909 rows x 5 columns]

# %% [markdown]
# ** Combine ecom2 and ecom3 with merge **

# %%
ecom_merge_2_3 = pd.merge(ecom2.iloc[:400],ecom3.iloc[:400], on='Total')

ecom_merge_2_3
# Out:
#        Total       Date InvoiceNo  CustomerID
# 0      15.30 2010-12-01    536365     17850.0
# 1      15.30 2010-12-01    536373     17850.0
# 2      15.30 2010-12-01    536373     17850.0
# 3      15.30 2010-12-01    536375     17850.0
# 4      15.30 2010-12-01    536375     17850.0
# ...      ...        ...       ...         ...
# 2187   22.95 2010-12-01    536401     15862.0
# 2188   16.95 2010-12-01    536401     15862.0
# 2189   10.65 2010-12-01    536401     15862.0
# 2190   13.90 2010-12-01    536401     15862.0
# 2191  153.00 2010-12-01    536402     15513.0
#
# [2192 rows x 4 columns]

# %% [markdown]
# ** Combine ecom2 and ecom3 with join **

# %%
join_ecom2_3 = ecom3.join(ecom2, how="inner",lsuffix="leftt",rsuffix="rightt")
join_ecom2_3
# Out:
#        InvoiceNo  CustomerID  Totalleftt  Totalrightt       Date
# 0         536365     17850.0       15.30        15.30 2010-12-01
# 1         536365     17850.0       20.34        20.34 2010-12-01
# 2         536365     17850.0       22.00        22.00 2010-12-01
# 3         536365     17850.0       20.34        20.34 2010-12-01
# 4         536365     17850.0       20.34        20.34 2010-12-01
# ...          ...         ...         ...          ...        ...
# 541904    581587     12680.0       10.20        10.20 2011-12-09
# 541905    581587     12680.0       12.60        12.60 2011-12-09
# 541906    581587     12680.0       16.60        16.60 2011-12-09
# 541907    581587     12680.0       16.60        16.60 2011-12-09
# 541908    581587     12680.0       14.85        14.85 2011-12-09
#
# [541909 rows x 5 columns]

# %% [markdown]
# # Congrats!

# %%
# Out:
#    InvoiceNo  CustomerID  Totalleftt  Totalrightt       Date
# 0     536365     17850.0       15.30        15.30 2010-12-01
# 1     536365     17850.0       20.34        20.34 2010-12-01
# 2     536365     17850.0       22.00        22.00 2010-12-01
# 3     536365     17850.0       20.34        20.34 2010-12-01
# 4     536365     17850.0       20.34        20.34 2010-12-01
# 5     536365     17850.0       15.30        15.30 2010-12-01
# 6     536365     17850.0       25.50        25.50 2010-12-01
# 7     536366     17850.0       11.10        11.10 2010-12-01
# 8     536366     17850.0       11.10        11.10 2010-12-01
# 9     536367     13047.0       54.08        54.08 2010-12-01
# 10    536367     13047.0       12.60        12.60 2010-12-01
# 11    536367     13047.0       12.60        12.60 2010-12-01
# 12    536367     13047.0       30.00        30.00 2010-12-01
# 13    536367     13047.0        9.90         9.90 2010-12-01
# 14    536367     13047.0       25.50        25.50 2010-12-01
# 15    536367     13047.0       14.85        14.85 2010-12-01
# 16    536367     13047.0       19.90        19.90 2010-12-01
# 17    536367     13047.0       17.85        17.85 2010-12-01
# 18    536367     13047.0       17.85        17.85 2010-12-01
# 19    536367     13047.0       31.80        31.80 2010-12-01
# 20    536367     13047.0       31.80        31.80 2010-12-01
# 21    536368     13047.0       25.50        25.50 2010-12-01
# 22    536368     13047.0       14.85        14.85 2010-12-01
# 23    536368     13047.0       14.85        14.85 2010-12-01
# 24    536368     13047.0       14.85        14.85 2010-12-01
# 25    536369     13047.0       17.85        17.85 2010-12-01
# 26    536370     12583.0       90.00        90.00 2010-12-01
# 27    536370     12583.0       90.00        90.00 2010-12-01
# 28    536370     12583.0       45.00        45.00 2010-12-01
# 29    536370     12583.0       10.20        10.20 2010-12-01
# 30    536370     12583.0       15.60        15.60 2010-12-01
# 31    536370     12583.0       40.80        40.80 2010-12-01
# 32    536370     12583.0       30.00        30.00 2010-12-01
